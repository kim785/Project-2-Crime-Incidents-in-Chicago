# %% [markdown]
# # Import Libraries

# %%
#Dependencies
import pandas as pd
import numpy as np
import json
import os
import requests 
import pymongo

# %% [markdown]
# # Perform API CALL

# %%
#Base URL for grabbing data from City Of Chicago
base_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson"

#Specify the Test URL with limit and offset parameters
#test_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit=50000&$offset=0&$order=id&$where=year>2017"

# %% [markdown]
# ### Define query paramerters to pull data from API

# %%
#Set parameter for API Call
offset= 0
limit = 50000 #50000
year =2020
record_counter =0

# Set empty lists to hold the combined data
crime_data = []

# %% [markdown]
# ### Paging through the data using query parameters

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")
#Paging through the data using query parameters - Loop through from pages
print(f"Loading first {limit} records.")
for i in range(1):
     query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&year={year}"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=year=2018"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=(year>2017&&year<2020)"
     print(f"Loading next {limit} records.")
     response = requests.get(query_url)
     data = response.json()
     #page = requests.get(f"https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit={limit}&$offset={offset}&$order=id&$where=year > 2017")
     offset += limit
     #crime_data += data
     crime_data = crime_data + data['features']
     #crime_data = crime_data + data["type"]
print("-----------------------------")
print(f"Data Retrieval Complete for {year}.Received {len(crime_data)} responses.")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Loading first 50000 records.
# Loading next 50000 records.
# -----------------------------
# Data Retrieval Complete for 2020.Received 50000 responses.

# %% [markdown]
# ### Data Validation & Preprocessing - JSON File

# %%
# Check the total number of json objects recieved
print(f"We received {len(crime_data)} responses.")
# Out:
# We received 50000 responses.

# %%
# View first json object
crime_data[0]
#print(f"The first response is {json.dumps(crime_data[0], indent=2)}.")
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]},
#  'properties': {'location_state': '',
#   'location_zip': '',
#   'x_coordinate': '1194878',
#   'domestic': False,
#   'latitude': '41.764728045',
#   'updated_on': '2020-06-20T15:48:45.000',
#   'description': 'FIRST DEGREE MURDER',
#   'location_address': '',
#   'arrest': True,
#   'location_city': '',
#   'year': '2020',
#   'longitude': '-87.561272312',
#   'block': '072XX S SOUTH SHORE DR',
#   'fbi_code': '01A',
#   'ward': '7',
#   'id': '24889',
#   'date': '2020-01-02T02:54:00.000',
#   'beat': '0334',
#   'y_coordinate': '1857803',
#   'community_area': '43',
#   'location_description': 'APARTMENT',
#   'district': '003',
#   'iucr': '0110',
#   'case_number': 'JD101272',
#   'primary_type': 'HOMICIDE'}}

# %% [markdown]
# #### Data Exploration using pandas to create summary table

# %%
#Normalizing the json objects to pandas - Validation Columns
crime_data_pd = pd.json_normalize(crime_data)
#crime_data_pd.dtypes

# %%
#Transforming trending date to datetime format
crime_data_pd['date'] = pd.to_datetime(crime_data_pd['properties.date'], format = '%Y-%m-%dT%H:%M:%S.%f')
#crime_data_pd.dtypes

# %%
#Checking for null values
print(crime_data_pd.isnull().sum())
# Out:
# type                                   0
# geometry.type                        232
# geometry.coordinates                 232
# properties.location_state            232
# properties.location_zip              232
# properties.x_coordinate              232
# properties.domestic                    0
# properties.latitude                  232
# properties.updated_on                  0
# properties.description                 0
# properties.location_address          232
# properties.arrest                      0
# properties.location_city             232
# properties.year                        0
# properties.longitude                 232
# properties.block                       0
# properties.fbi_code                    0
# properties.ward                        1
# properties.id                          0
# properties.date                        0
# properties.beat                        0
# properties.y_coordinate              232
# properties.community_area              0
# properties.location_description      177
# properties.district                    0
# properties.iucr                        0
# properties.case_number                 0
# properties.primary_type                0
# geometry                           50000
# date                                   0
# dtype: int64

# %%
crime_data_pd['crime_month'] =crime_data_pd['date'].dt.month
crime_data_pd['crime_month_name'] =crime_data_pd['date'].dt.month_name()

# %%
#Creating a Data Frame with Selected Columns
crime_data_df = crime_data_pd[['properties.id','properties.year','crime_month','crime_month_name','properties.description','properties.location_description',
                               'properties.primary_type','properties.arrest','properties.domestic']]

# %%
crime_data_df = crime_data_df.rename(columns=
                                      { "properties.id":"id", "properties.year":"year", "properties.arrest":"arrest",
                                        "properties.primary_type":"primary_type", "properties.domestic":"domestic",
                                        "properties.description":"description", "properties.location_description":"location_description"})

# %%
crime_data_df.head()
# Out:
#       id  year  crime_month crime_month_name          description  \
# 0  24889  2020            1          January  FIRST DEGREE MURDER
# 1  24890  2020            1          January  FIRST DEGREE MURDER
# 2  24891  2020            1          January  FIRST DEGREE MURDER
# 3  24892  2020            1          January  FIRST DEGREE MURDER
# 4  24893  2020            1          January  FIRST DEGREE MURDER
#
#   location_description primary_type  arrest  domestic
# 0            APARTMENT     HOMICIDE    True     False
# 1            APARTMENT     HOMICIDE    True     False
# 2               STREET     HOMICIDE    True     False
# 3               STREET     HOMICIDE   False     False
# 4         RETAIL STORE     HOMICIDE    True     False

# %%
crime_count= crime_data_df.groupby(['crime_month_name','primary_type'])['id'].count()
crime_type_summary = pd.DataFrame({'reported_crime':crime_count})
crime_type_summary =crime_type_summary.reset_index()

# %%
crime_type_dict =crime_type_summary.to_dict('records')
crime_type_dict
# Out:
# [{'crime_month_name': 'April',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 62},
#  {'crime_month_name': 'August',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 67},
#  {'crime_month_name': 'December',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 55},
#  {'crime_month_name': 'February',
#   'primary_type': 'ARSON',
#   'reported_crime': 31},
#  {'crime_month_name': 'February',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1379},
#  {'crime_month_name': 'February',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3371},
#  {'crime_month_name': 'February',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 609},
#  {'crime_month_name': 'February',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 22},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1733},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 85},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 534},
#  {'crime_month_name': 'February',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1176},
#  {'crime_month_name': 'February',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 38},
#  {'crime_month_name': 'February',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'crime_month_name': 'February',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 116},
#  {'crime_month_name': 'February',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'crime_month_name': 'February',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 21},
#  {'crime_month_name': 'February',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 640},
#  {'crime_month_name': 'February',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1117},
#  {'crime_month_name': 'February',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 2},
#  {'crime_month_name': 'February',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 188},
#  {'crime_month_name': 'February',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 1},
#  {'crime_month_name': 'February',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1204},
#  {'crime_month_name': 'February',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 27},
#  {'crime_month_name': 'February',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 2},
#  {'crime_month_name': 'February',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 87},
#  {'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 634},
#  {'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 79},
#  {'crime_month_name': 'February',
#   'primary_type': 'STALKING',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'reported_crime': 4091},
#  {'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 460},
#  {'crime_month_name': 'January',
#   'primary_type': 'ARSON',
#   'reported_crime': 23},
#  {'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1512},
#  {'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3589},
#  {'crime_month_name': 'January',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 730},
#  {'crime_month_name': 'January',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 53},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1779},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 77},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 573},
#  {'crime_month_name': 'January',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1350},
#  {'crime_month_name': 'January',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 2},
#  {'crime_month_name': 'January',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 36},
#  {'crime_month_name': 'January',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 121},
#  {'crime_month_name': 'January',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 9},
#  {'crime_month_name': 'January',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'crime_month_name': 'January',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'January',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 664},
#  {'crime_month_name': 'January',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1259},
#  {'crime_month_name': 'January',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 6},
#  {'crime_month_name': 'January',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 193},
#  {'crime_month_name': 'January',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'crime_month_name': 'January',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1387},
#  {'crime_month_name': 'January',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 38},
#  {'crime_month_name': 'January',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 107},
#  {'crime_month_name': 'January',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 725},
#  {'crime_month_name': 'January',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 83},
#  {'crime_month_name': 'January',
#   'primary_type': 'STALKING',
#   'reported_crime': 13},
#  {'crime_month_name': 'January',
#   'primary_type': 'THEFT',
#   'reported_crime': 4546},
#  {'crime_month_name': 'January',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 490},
#  {'crime_month_name': 'July',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 109},
#  {'crime_month_name': 'June',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 94},
#  {'crime_month_name': 'March', 'primary_type': 'ARSON', 'reported_crime': 18},
#  {'crime_month_name': 'March',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1130},
#  {'crime_month_name': 'March',
#   'primary_type': 'BATTERY',
#   'reported_crime': 2717},
#  {'crime_month_name': 'March',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 373},
#  {'crime_month_name': 'March',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 10},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1395},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 73},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 312},
#  {'crime_month_name': 'March',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 609},
#  {'crime_month_name': 'March',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 4},
#  {'crime_month_name': 'March',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 29},
#  {'crime_month_name': 'March',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 76},
#  {'crime_month_name': 'March',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 4},
#  {'crime_month_name': 'March',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 6},
#  {'crime_month_name': 'March',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 11},
#  {'crime_month_name': 'March',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 449},
#  {'crime_month_name': 'March',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 643},
#  {'crime_month_name': 'March',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 1},
#  {'crime_month_name': 'March',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 113},
#  {'crime_month_name': 'March',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'crime_month_name': 'March',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 801},
#  {'crime_month_name': 'March',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 18},
#  {'crime_month_name': 'March',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'crime_month_name': 'March',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 64},
#  {'crime_month_name': 'March',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 370},
#  {'crime_month_name': 'March',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 47},
#  {'crime_month_name': 'March',
#   'primary_type': 'STALKING',
#   'reported_crime': 12},
#  {'crime_month_name': 'March',
#   'primary_type': 'THEFT',
#   'reported_crime': 2561},
#  {'crime_month_name': 'March',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 360},
#  {'crime_month_name': 'May', 'primary_type': 'HOMICIDE', 'reported_crime': 85},
#  {'crime_month_name': 'November',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 62},
#  {'crime_month_name': 'October',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 66},
#  {'crime_month_name': 'September',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 82}]

# %% [markdown]
# ### Loading Data to MONGODB  Database

# %% [markdown]
# #### Cleaning the raw json by removing extra columns

# %%
# Get rid of unnecessary columns
for property in crime_data:
    properties = (property['properties'])
    del (properties['iucr'])
    del (properties['updated_on'])
    del (properties['fbi_code'])
    del (properties['case_number'])
    del (properties['ward'])   
    del (properties['beat'])
    del (properties['community_area'])
    del (properties['location_zip'])
    del (properties['location_city'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-f374668a0e79> in <module>
#       2 for property in crime_data:
#       3     properties = (property['properties'])
# ----> 4     del (properties['iucr'])
#       5     del (properties['updated_on'])
#       6     del (properties['fbi_code'])
#
# KeyError: 'iucr'

# %%
crime_data[0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]},
#  'properties': {'location_state': '',
#   'x_coordinate': '1194878',
#   'domestic': False,
#   'latitude': '41.764728045',
#   'description': 'FIRST DEGREE MURDER',
#   'location_address': '',
#   'arrest': True,
#   'year': '2020',
#   'longitude': '-87.561272312',
#   'block': '072XX S SOUTH SHORE DR',
#   'id': '24889',
#   'date': '2020-01-02T02:54:00.000',
#   'y_coordinate': '1857803',
#   'location_description': 'APARTMENT',
#   'district': '003',
#   'primary_type': 'HOMICIDE'},
#  '_id': ObjectId('617b3e16fa0bfcfc22e9404c')}

# %%
conn = 'mongodb://localhost:27017'
#conn = 'mongodb+srv://chicago_crime_user:chicago_crime_password@cluster0.opshg.mongodb.net/CHICAGO_CRIME_GROUPPROJECT?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime

# %%
collection = db.events

# %%
collection.insert_many(crime_data)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# <ipython-input-40-c85fc67e32b7> in <module>
# ----> 1 collection.insert_many(crime_data)
#
# /Applications/anaconda3/lib/python3.8/site-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     768         blk = _Bulk(self, ordered, bypass_document_validation)
#     769         blk.ops = [doc for doc in gen()]
# --> 770         blk.execute(write_concern, session=session)
#     771         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     772
#
# /Applications/anaconda3/lib/python3.8/site-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     527                 self.execute_no_results(sock_info, generator)
#     528         else:
# --> 529             return self.execute_command(generator, write_concern, session)
#     530
#     531
#
# /Applications/anaconda3/lib/python3.8/site-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     362
#     363         if full_result["writeErrors"] or full_result["writeConcernErrors"]:
# --> 364             _raise_bulk_write_error(full_result)
#     365         return full_result
#     366
#
# /Applications/anaconda3/lib/python3.8/site-packages/pymongo/bulk.py in _raise_bulk_write_error(full_result)
#     138         full_result["writeErrors"].sort(
#     139             key=lambda error: error["index"])
# --> 140     raise BulkWriteError(full_result)
#     141
#     142
#
# BulkWriteError: batch op errors occurred, full error: {'writeErrors': [{'index': 0, 'code': 11000, 'keyPattern': {'_id': 1}, 'keyValue': {'_id': ObjectId('617b3e16fa0bfcfc22e9404c')}, 'errmsg': "E11000 duplicate key error collection: chicago_crime.events index: _id_ dup key: { _id: ObjectId('617b3e16fa0bfcfc22e9404c') }", 'op': {'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]}, 'properties': {'location_state': '', 'x_coordinate': '1194878', 'domestic': False, 'latitude': '41.764728045', 'description': 'FIRST DEGREE MURDER', 'location_address': '', 'arrest': True, 'year': '2020', 'longitude': '-87.561272312', 'block': '072XX S SOUTH SHORE DR', 'id': '24889', 'date': '2020-01-02T02:54:00.000', 'y_coordinate': '1857803', 'location_description': 'APARTMENT', 'district': '003', 'primary_type': 'HOMICIDE'}, '_id': ObjectId('617b3e16fa0bfcfc22e9404c')}}], 'writeConcernErrors': [], 'nInserted': 0, 'nUpserted': 0, 'nMatched': 0, 'nModified': 0, 'nRemoved': 0, 'upserted': []}

# %%
# query the classroom collection in flask application
#classroom = db.classroom.find()
crime = collection.find()

# %%
crime.count()

# %% [markdown]
# ### Loading Crime Type Dictonary in Mongo Shared

# %%
#conn = 'mongodb+srv://chicago_crime_user:chicago_crime_password@cluster0.opshg.mongodb.net/CHICAGO_CRIME_GROUPPROJECT?retryWrites=true&w=majority'
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime
collection = db.crime_type_summary

collection.insert_many(crime_type_dict)  
# collection.find_one()

# %%
db = client.chicago_crime.crime_type_summary
# crime_type_summary = db

summary = crime_type_summary.find_one()

print(summary)
# Out:
# {'_id': ObjectId('617b3ed4fa0bfcfc22ea03bd'), 'crime_month_name': 'April', 'primary_type': 'HOMICIDE', 'reported_crime': 62}

# %%
# REMEMBER TO UNCOMMENT TO INSERT DATA

# %%
# Out:
# None

# %%
print(crime_type_dict)
# Out:
# [{'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'ARSON', 'reported_crime': 72, '_id': ObjectId('617b3e2cfa0bfcfc22ea039d')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'ASSAULT', 'reported_crime': 4021, '_id': ObjectId('617b3e2cfa0bfcfc22ea039e')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'BATTERY', 'reported_crime': 9677, '_id': ObjectId('617b3e2cfa0bfcfc22ea039f')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'BURGLARY', 'reported_crime': 1712, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a0')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'CONCEALED CARRY LICENSE VIOLATION', 'reported_crime': 38, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a1')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'CRIM SEXUAL ASSAULT', 'reported_crime': 75, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a2')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'CRIMINAL DAMAGE', 'reported_crime': 4907, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a3')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'CRIMINAL SEXUAL ASSAULT', 'reported_crime': 235, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a4')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'CRIMINAL TRESPASS', 'reported_crime': 1419, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a5')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'DECEPTIVE PRACTICE', 'reported_crime': 3135, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a6')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'GAMBLING', 'reported_crime': 6, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a7')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'HOMICIDE', 'reported_crime': 785, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a8')}, {'crime_month_name': <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x7f93243ee190>>, 'primary_type': 'HUMAN TRAFFICKING', 'reported_crime': 1, '_id': ObjectId('617b3e2cfa0bfcfc22ea03a9')}, {'crime_month_name': <bound method PandasDelegate._add_del ...

# %% [markdown]
# ## Jay Time

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db = client.chicago_crime.crime_type_summary

data = db.find()

# %%
new_data = []
for dictionary in data:
    new_d = {k:v for k,v in dictionary.items() if k != '_id'}
    new_data.append(new_d)

new_data
# Out:
# [{'crime_month_name': 'April',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 62},
#  {'crime_month_name': 'August',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 67},
#  {'crime_month_name': 'December',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 55},
#  {'crime_month_name': 'February',
#   'primary_type': 'ARSON',
#   'reported_crime': 31},
#  {'crime_month_name': 'February',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1379},
#  {'crime_month_name': 'February',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3371},
#  {'crime_month_name': 'February',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 609},
#  {'crime_month_name': 'February',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 22},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1733},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 85},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 534},
#  {'crime_month_name': 'February',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1176},
#  {'crime_month_name': 'February',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 38},
#  {'crime_month_name': 'February',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'crime_month_name': 'February',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 116},
#  {'crime_month_name': 'February',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'crime_month_name': 'February',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 21},
#  {'crime_month_name': 'February',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 640},
#  {'crime_month_name': 'February',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1117},
#  {'crime_month_name': 'February',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 2},
#  {'crime_month_name': 'February',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 188},
#  {'crime_month_name': 'February',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 1},
#  {'crime_month_name': 'February',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1204},
#  {'crime_month_name': 'February',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 27},
#  {'crime_month_name': 'February',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 2},
#  {'crime_month_name': 'February',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 87},
#  {'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 634},
#  {'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 79},
#  {'crime_month_name': 'February',
#   'primary_type': 'STALKING',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'reported_crime': 4091},
#  {'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 460},
#  {'crime_month_name': 'January',
#   'primary_type': 'ARSON',
#   'reported_crime': 23},
#  {'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1512},
#  {'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3589},
#  {'crime_month_name': 'January',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 730},
#  {'crime_month_name': 'January',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 53},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1779},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 77},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 573},
#  {'crime_month_name': 'January',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1350},
#  {'crime_month_name': 'January',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 2},
#  {'crime_month_name': 'January',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 36},
#  {'crime_month_name': 'January',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 121},
#  {'crime_month_name': 'January',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 9},
#  {'crime_month_name': 'January',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'crime_month_name': 'January',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'January',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 664},
#  {'crime_month_name': 'January',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1259},
#  {'crime_month_name': 'January',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 6},
#  {'crime_month_name': 'January',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 193},
#  {'crime_month_name': 'January',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'crime_month_name': 'January',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1387},
#  {'crime_month_name': 'January',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 38},
#  {'crime_month_name': 'January',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 107},
#  {'crime_month_name': 'January',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 725},
#  {'crime_month_name': 'January',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 83},
#  {'crime_month_name': 'January',
#   'primary_type': 'STALKING',
#   'reported_crime': 13},
#  {'crime_month_name': 'January',
#   'primary_type': 'THEFT',
#   'reported_crime': 4546},
#  {'crime_month_name': 'January',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 490},
#  {'crime_month_name': 'July',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 109},
#  {'crime_month_name': 'June',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 94},
#  {'crime_month_name': 'March', 'primary_type': 'ARSON', 'reported_crime': 18},
#  {'crime_month_name': 'March',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1130},
#  {'crime_month_name': 'March',
#   'primary_type': 'BATTERY',
#   'reported_crime': 2717},
#  {'crime_month_name': 'March',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 373},
#  {'crime_month_name': 'March',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 10},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1395},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 73},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 312},
#  {'crime_month_name': 'March',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 609},
#  {'crime_month_name': 'March',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 4},
#  {'crime_month_name': 'March',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 29},
#  {'crime_month_name': 'March',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 76},
#  {'crime_month_name': 'March',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 4},
#  {'crime_month_name': 'March',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 6},
#  {'crime_month_name': 'March',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 11},
#  {'crime_month_name': 'March',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 449},
#  {'crime_month_name': 'March',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 643},
#  {'crime_month_name': 'March',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 1},
#  {'crime_month_name': 'March',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 113},
#  {'crime_month_name': 'March',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'crime_month_name': 'March',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 801},
#  {'crime_month_name': 'March',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 18},
#  {'crime_month_name': 'March',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'crime_month_name': 'March',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 64},
#  {'crime_month_name': 'March',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 370},
#  {'crime_month_name': 'March',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 47},
#  {'crime_month_name': 'March',
#   'primary_type': 'STALKING',
#   'reported_crime': 12},
#  {'crime_month_name': 'March',
#   'primary_type': 'THEFT',
#   'reported_crime': 2561},
#  {'crime_month_name': 'March',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 360},
#  {'crime_month_name': 'May', 'primary_type': 'HOMICIDE', 'reported_crime': 85},
#  {'crime_month_name': 'November',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 62},
#  {'crime_month_name': 'October',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 66},
#  {'crime_month_name': 'September',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 82}]
