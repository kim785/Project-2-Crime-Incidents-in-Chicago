# %% [markdown]
# # Import Libraries

# %%
#Dependencies
import pandas as pd
import numpy as np
import json
import os
import requests 
import pymongo

# %% [markdown]
# # Perform API CALL

# %%
#Base URL for grabbing data from City Of Chicago
base_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson"

#Specify the Test URL with limit and offset parameters
#test_url ="https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit=50000&$offset=0&$order=id&$where=year>2017"

# %% [markdown]
# ### Define query paramerters to pull data from API

# %%
#Set parameter for API Call
offset= 0
limit = 50000 #50000
year =2020
record_counter =0

# Set empty lists to hold the combined data
crime_data = []

# %% [markdown]
# ### Paging through the data using query parameters

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")
#Paging through the data using query parameters - Loop through from pages
print(f"Loading first {limit} records.")
for i in range(5):
     query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&year={year}"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=year=2018"
     #query_url =f"{base_url}?$limit={limit}&$offset={offset}&$order=id&$where=(year>2017&&year<2020)"
     print(f"Loading next {limit} records.")
     response = requests.get(query_url)
     data = response.json()
     #page = requests.get(f"https://data.cityofchicago.org/resource/ijzp-q8t2.geojson?$limit={limit}&$offset={offset}&$order=id&$where=year > 2017")
     offset += limit
     #crime_data += data
     crime_data = crime_data + data['features']
     #crime_data = crime_data + data["type"]
print("-----------------------------")
print(f"Data Retrieval Complete for {year}.Received {len(crime_data)} responses.")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Loading first 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# Loading next 50000 records.
# -----------------------------
# Data Retrieval Complete for 2020.Received 211359 responses.

# %% [markdown]
# ### Data Validation & Preprocessing - JSON File

# %%
# Check the total number of json objects recieved
print(f"We received {len(crime_data)} responses.")
# Out:
# We received 211359 responses.

# %%
# View first json object
crime_data[0]
#print(f"The first response is {json.dumps(crime_data[0], indent=2)}.")
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]},
#  'properties': {'location_state': '',
#   'location_zip': '',
#   'x_coordinate': '1194878',
#   'domestic': False,
#   'latitude': '41.764728045',
#   'updated_on': '2020-06-20T15:48:45.000',
#   'description': 'FIRST DEGREE MURDER',
#   'location_address': '',
#   'arrest': True,
#   'location_city': '',
#   'year': '2020',
#   'longitude': '-87.561272312',
#   'block': '072XX S SOUTH SHORE DR',
#   'fbi_code': '01A',
#   'ward': '7',
#   'id': '24889',
#   'date': '2020-01-02T02:54:00.000',
#   'beat': '0334',
#   'y_coordinate': '1857803',
#   'community_area': '43',
#   'location_description': 'APARTMENT',
#   'district': '003',
#   'iucr': '0110',
#   'case_number': 'JD101272',
#   'primary_type': 'HOMICIDE'}}

# %% [markdown]
# #### Data Exploration using pandas to create summary table

# %%
#Normalizing the json objects to pandas - Validation Columns
crime_data_pd = pd.json_normalize(crime_data)
#crime_data_pd.dtypes

# %%
#Transforming trending date to datetime format
crime_data_pd['date'] = pd.to_datetime(crime_data_pd['properties.date'], format = '%Y-%m-%dT%H:%M:%S.%f')
#crime_data_pd.dtypes

# %%
#Checking for null values
print(crime_data_pd.isnull().sum())
# Out:
# type                                    0
# geometry.type                        2896
# geometry.coordinates                 2896
# properties.location_state            2896
# properties.location_zip              2896
# properties.x_coordinate              2896
# properties.domestic                     0
# properties.latitude                  2896
# properties.updated_on                   0
# properties.description                  0
# properties.location_address          2896
# properties.arrest                       0
# properties.location_city             2896
# properties.year                         0
# properties.longitude                 2896
# properties.block                        0
# properties.fbi_code                     0
# properties.ward                         9
# properties.id                           0
# properties.date                         0
# properties.beat                         0
# properties.y_coordinate              2896
# properties.community_area               1
# properties.location_description      1216
# properties.district                     0
# properties.iucr                         0
# properties.case_number                  0
# properties.primary_type                 0
# geometry                           211359
# date                                    0
# dtype: int64

# %%
crime_data_pd['crime_month'] =crime_data_pd['date'].dt.month
crime_data_pd['crime_month_name'] =crime_data_pd['date'].dt.month_name(locale='English')

# %%
#Creating a Data Frame with Selected Columns
crime_data_df = crime_data_pd[['properties.id','properties.year','crime_month','crime_month_name','properties.description','properties.location_description',
                               'properties.primary_type','properties.arrest','properties.domestic']]

# %%
crime_data_df = crime_data_df.rename(columns=
                                      { "properties.id":"id", "properties.year":"year", "properties.arrest":"arrest",
                                        "properties.primary_type":"primary_type", "properties.domestic":"domestic",
                                        "properties.description":"description", "properties.location_description":"location_description"})

# %%
crime_data_df.head()
# Out:
#       id  year  crime_month crime_month_name          description  \
# 0  24889  2020            1          January  FIRST DEGREE MURDER
# 1  24890  2020            1          January  FIRST DEGREE MURDER
# 2  24891  2020            1          January  FIRST DEGREE MURDER
# 3  24892  2020            1          January  FIRST DEGREE MURDER
# 4  24893  2020            1          January  FIRST DEGREE MURDER
#
#   location_description primary_type  arrest  domestic
# 0            APARTMENT     HOMICIDE    True     False
# 1            APARTMENT     HOMICIDE    True     False
# 2               STREET     HOMICIDE    True     False
# 3               STREET     HOMICIDE   False     False
# 4         RETAIL STORE     HOMICIDE    True     False

# %%
crime_count= crime_data_df.groupby(['crime_month_name','primary_type'])['id'].count()
crime_type_summary = pd.DataFrame({'reported_crime':crime_count})
crime_type_summary =crime_type_summary.reset_index()

# %%
crime_type_dict =crime_type_summary.to_dict('records')
crime_type_dict
# Out:
# [{'crime_month_name': 'April', 'primary_type': 'ARSON', 'reported_crime': 35},
#  {'crime_month_name': 'April',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1112},
#  {'crime_month_name': 'April',
#   'primary_type': 'BATTERY',
#   'reported_crime': 2693},
#  {'crime_month_name': 'April',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 527},
#  {'crime_month_name': 'April',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 7},
#  {'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1782},
#  {'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 60},
#  {'crime_month_name': 'April',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 235},
#  {'crime_month_name': 'April',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1091},
#  {'crime_month_name': 'April',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 62},
#  {'crime_month_name': 'April',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 17},
#  {'crime_month_name': 'April',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 4},
#  {'crime_month_name': 'April',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 3},
#  {'crime_month_name': 'April',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 1},
#  {'crime_month_name': 'April',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 659},
#  {'crime_month_name': 'April',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 179},
#  {'crime_month_name': 'April',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 4},
#  {'crime_month_name': 'April',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 128},
#  {'crime_month_name': 'April',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 742},
#  {'crime_month_name': 'April',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 2},
#  {'crime_month_name': 'April',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 39},
#  {'crime_month_name': 'April',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 455},
#  {'crime_month_name': 'April',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 58},
#  {'crime_month_name': 'April',
#   'primary_type': 'STALKING',
#   'reported_crime': 8},
#  {'crime_month_name': 'April',
#   'primary_type': 'THEFT',
#   'reported_crime': 2500},
#  {'crime_month_name': 'April',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 474},
#  {'crime_month_name': 'August', 'primary_type': 'ARSON', 'reported_crime': 57},
#  {'crime_month_name': 'August',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1835},
#  {'crime_month_name': 'August',
#   'primary_type': 'BATTERY',
#   'reported_crime': 4073},
#  {'crime_month_name': 'August',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 1062},
#  {'crime_month_name': 'August',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 11},
#  {'crime_month_name': 'August',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2364},
#  {'crime_month_name': 'August',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 106},
#  {'crime_month_name': 'August',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 342},
#  {'crime_month_name': 'August',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1159},
#  {'crime_month_name': 'August',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 3},
#  {'crime_month_name': 'August',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 67},
#  {'crime_month_name': 'August',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 50},
#  {'crime_month_name': 'August',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'August',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'crime_month_name': 'August',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 28},
#  {'crime_month_name': 'August',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 997},
#  {'crime_month_name': 'August',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 552},
#  {'crime_month_name': 'August',
#   'primary_type': 'NON-CRIMINAL',
#   'reported_crime': 1},
#  {'crime_month_name': 'August',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 5},
#  {'crime_month_name': 'August',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 122},
#  {'crime_month_name': 'August',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 1},
#  {'crime_month_name': 'August',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1096},
#  {'crime_month_name': 'August',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 9},
#  {'crime_month_name': 'August',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 2},
#  {'crime_month_name': 'August',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 92},
#  {'crime_month_name': 'August',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 816},
#  {'crime_month_name': 'August',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 93},
#  {'crime_month_name': 'August',
#   'primary_type': 'STALKING',
#   'reported_crime': 23},
#  {'crime_month_name': 'August',
#   'primary_type': 'THEFT',
#   'reported_crime': 3879},
#  {'crime_month_name': 'August',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 983},
#  {'crime_month_name': 'December',
#   'primary_type': 'ARSON',
#   'reported_crime': 40},
#  {'crime_month_name': 'December',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1273},
#  {'crime_month_name': 'December',
#   'primary_type': 'BATTERY',
#   'reported_crime': 2729},
#  {'crime_month_name': 'December',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 546},
#  {'crime_month_name': 'December',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 8},
#  {'crime_month_name': 'December',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1670},
#  {'crime_month_name': 'December',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 71},
#  {'crime_month_name': 'December',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 265},
#  {'crime_month_name': 'December',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 2818},
#  {'crime_month_name': 'December',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 55},
#  {'crime_month_name': 'December',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 40},
#  {'crime_month_name': 'December',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 6},
#  {'crime_month_name': 'December',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 6},
#  {'crime_month_name': 'December',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 4},
#  {'crime_month_name': 'December',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 909},
#  {'crime_month_name': 'December',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 514},
#  {'crime_month_name': 'December',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 3},
#  {'crime_month_name': 'December',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 162},
#  {'crime_month_name': 'December',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 932},
#  {'crime_month_name': 'December',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 4},
#  {'crime_month_name': 'December',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 45},
#  {'crime_month_name': 'December',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 565},
#  {'crime_month_name': 'December',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 55},
#  {'crime_month_name': 'December',
#   'primary_type': 'STALKING',
#   'reported_crime': 15},
#  {'crime_month_name': 'December',
#   'primary_type': 'THEFT',
#   'reported_crime': 2910},
#  {'crime_month_name': 'December',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 765},
#  {'crime_month_name': 'February',
#   'primary_type': 'ARSON',
#   'reported_crime': 31},
#  {'crime_month_name': 'February',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1386},
#  {'crime_month_name': 'February',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3386},
#  {'crime_month_name': 'February',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 618},
#  {'crime_month_name': 'February',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 22},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1742},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 94},
#  {'crime_month_name': 'February',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 535},
#  {'crime_month_name': 'February',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1351},
#  {'crime_month_name': 'February',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 38},
#  {'crime_month_name': 'February',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 2},
#  {'crime_month_name': 'February',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 116},
#  {'crime_month_name': 'February',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'February',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'crime_month_name': 'February',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 21},
#  {'crime_month_name': 'February',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 652},
#  {'crime_month_name': 'February',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1177},
#  {'crime_month_name': 'February',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 2},
#  {'crime_month_name': 'February',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 204},
#  {'crime_month_name': 'February',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 1},
#  {'crime_month_name': 'February',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1243},
#  {'crime_month_name': 'February',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 27},
#  {'crime_month_name': 'February',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 2},
#  {'crime_month_name': 'February',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 87},
#  {'crime_month_name': 'February',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 637},
#  {'crime_month_name': 'February',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 90},
#  {'crime_month_name': 'February',
#   'primary_type': 'STALKING',
#   'reported_crime': 18},
#  {'crime_month_name': 'February',
#   'primary_type': 'THEFT',
#   'reported_crime': 4176},
#  {'crime_month_name': 'February',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 461},
#  {'crime_month_name': 'January',
#   'primary_type': 'ARSON',
#   'reported_crime': 23},
#  {'crime_month_name': 'January',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1519},
#  {'crime_month_name': 'January',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3606},
#  {'crime_month_name': 'January',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 740},
#  {'crime_month_name': 'January',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIM SEXUAL ASSAULT',
#   'reported_crime': 53},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1791},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 96},
#  {'crime_month_name': 'January',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 575},
#  {'crime_month_name': 'January',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1542},
#  {'crime_month_name': 'January',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 2},
#  {'crime_month_name': 'January',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 36},
#  {'crime_month_name': 'January',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 121},
#  {'crime_month_name': 'January',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 9},
#  {'crime_month_name': 'January',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'crime_month_name': 'January',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'January',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 668},
#  {'crime_month_name': 'January',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 1292},
#  {'crime_month_name': 'January',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 6},
#  {'crime_month_name': 'January',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 218},
#  {'crime_month_name': 'January',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'crime_month_name': 'January',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1419},
#  {'crime_month_name': 'January',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 38},
#  {'crime_month_name': 'January',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 107},
#  {'crime_month_name': 'January',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 725},
#  {'crime_month_name': 'January',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 92},
#  {'crime_month_name': 'January',
#   'primary_type': 'STALKING',
#   'reported_crime': 13},
#  {'crime_month_name': 'January',
#   'primary_type': 'THEFT',
#   'reported_crime': 4600},
#  {'crime_month_name': 'January',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 490},
#  {'crime_month_name': 'July', 'primary_type': 'ARSON', 'reported_crime': 63},
#  {'crime_month_name': 'July',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1890},
#  {'crime_month_name': 'July',
#   'primary_type': 'BATTERY',
#   'reported_crime': 4149},
#  {'crime_month_name': 'July',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 737},
#  {'crime_month_name': 'July',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 14},
#  {'crime_month_name': 'July',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2503},
#  {'crime_month_name': 'July',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 113},
#  {'crime_month_name': 'July',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 308},
#  {'crime_month_name': 'July',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1347},
#  {'crime_month_name': 'July', 'primary_type': 'GAMBLING', 'reported_crime': 2},
#  {'crime_month_name': 'July',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 111},
#  {'crime_month_name': 'July',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'crime_month_name': 'July',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 43},
#  {'crime_month_name': 'July',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 21},
#  {'crime_month_name': 'July',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 8},
#  {'crime_month_name': 'July',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 29},
#  {'crime_month_name': 'July',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 957},
#  {'crime_month_name': 'July',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 517},
#  {'crime_month_name': 'July',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 7},
#  {'crime_month_name': 'July',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 164},
#  {'crime_month_name': 'July',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1113},
#  {'crime_month_name': 'July',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 80},
#  {'crime_month_name': 'July',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 77},
#  {'crime_month_name': 'July',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 734},
#  {'crime_month_name': 'July',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 100},
#  {'crime_month_name': 'July',
#   'primary_type': 'STALKING',
#   'reported_crime': 16},
#  {'crime_month_name': 'July', 'primary_type': 'THEFT', 'reported_crime': 3662},
#  {'crime_month_name': 'July',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 804},
#  {'crime_month_name': 'June', 'primary_type': 'ARSON', 'reported_crime': 74},
#  {'crime_month_name': 'June',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1724},
#  {'crime_month_name': 'June',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3919},
#  {'crime_month_name': 'June',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 753},
#  {'crime_month_name': 'June',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'June',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2449},
#  {'crime_month_name': 'June',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 99},
#  {'crime_month_name': 'June',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 284},
#  {'crime_month_name': 'June',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1117},
#  {'crime_month_name': 'June', 'primary_type': 'GAMBLING', 'reported_crime': 6},
#  {'crime_month_name': 'June',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 94},
#  {'crime_month_name': 'June',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 28},
#  {'crime_month_name': 'June',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 22},
#  {'crime_month_name': 'June',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'crime_month_name': 'June',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 1},
#  {'crime_month_name': 'June',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 794},
#  {'crime_month_name': 'June',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 338},
#  {'crime_month_name': 'June',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 6},
#  {'crime_month_name': 'June',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 153},
#  {'crime_month_name': 'June',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 963},
#  {'crime_month_name': 'June',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 31},
#  {'crime_month_name': 'June',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 156},
#  {'crime_month_name': 'June',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 574},
#  {'crime_month_name': 'June',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 86},
#  {'crime_month_name': 'June',
#   'primary_type': 'STALKING',
#   'reported_crime': 22},
#  {'crime_month_name': 'June', 'primary_type': 'THEFT', 'reported_crime': 3075},
#  {'crime_month_name': 'June',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 782},
#  {'crime_month_name': 'March', 'primary_type': 'ARSON', 'reported_crime': 27},
#  {'crime_month_name': 'March',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1476},
#  {'crime_month_name': 'March',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3560},
#  {'crime_month_name': 'March',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 567},
#  {'crime_month_name': 'March',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 11},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1892},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 106},
#  {'crime_month_name': 'March',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 394},
#  {'crime_month_name': 'March',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1181},
#  {'crime_month_name': 'March',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 4},
#  {'crime_month_name': 'March',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 29},
#  {'crime_month_name': 'March',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 81},
#  {'crime_month_name': 'March',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 7},
#  {'crime_month_name': 'March',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 8},
#  {'crime_month_name': 'March',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 11},
#  {'crime_month_name': 'March',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 628},
#  {'crime_month_name': 'March',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 741},
#  {'crime_month_name': 'March',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 2},
#  {'crime_month_name': 'March',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 161},
#  {'crime_month_name': 'March',
#   'primary_type': 'OTHER NARCOTIC VIOLATION',
#   'reported_crime': 2},
#  {'crime_month_name': 'March',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1110},
#  {'crime_month_name': 'March',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 19},
#  {'crime_month_name': 'March',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'crime_month_name': 'March',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 80},
#  {'crime_month_name': 'March',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 495},
#  {'crime_month_name': 'March',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 84},
#  {'crime_month_name': 'March',
#   'primary_type': 'STALKING',
#   'reported_crime': 20},
#  {'crime_month_name': 'March',
#   'primary_type': 'THEFT',
#   'reported_crime': 3525},
#  {'crime_month_name': 'March',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 464},
#  {'crime_month_name': 'May', 'primary_type': 'ARSON', 'reported_crime': 78},
#  {'crime_month_name': 'May',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1488},
#  {'crime_month_name': 'May',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3505},
#  {'crime_month_name': 'May',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 1323},
#  {'crime_month_name': 'May',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 12},
#  {'crime_month_name': 'May',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2477},
#  {'crime_month_name': 'May',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 91},
#  {'crime_month_name': 'May',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 277},
#  {'crime_month_name': 'May',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1023},
#  {'crime_month_name': 'May', 'primary_type': 'GAMBLING', 'reported_crime': 1},
#  {'crime_month_name': 'May', 'primary_type': 'HOMICIDE', 'reported_crime': 86},
#  {'crime_month_name': 'May',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'crime_month_name': 'May',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 37},
#  {'crime_month_name': 'May',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 10},
#  {'crime_month_name': 'May',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 11},
#  {'crime_month_name': 'May',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 4},
#  {'crime_month_name': 'May',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 829},
#  {'crime_month_name': 'May',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 484},
#  {'crime_month_name': 'May', 'primary_type': 'OBSCENITY', 'reported_crime': 7},
#  {'crime_month_name': 'May',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 147},
#  {'crime_month_name': 'May',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 879},
#  {'crime_month_name': 'May',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 11},
#  {'crime_month_name': 'May',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'crime_month_name': 'May',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 408},
#  {'crime_month_name': 'May', 'primary_type': 'ROBBERY', 'reported_crime': 598},
#  {'crime_month_name': 'May',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 62},
#  {'crime_month_name': 'May', 'primary_type': 'STALKING', 'reported_crime': 10},
#  {'crime_month_name': 'May', 'primary_type': 'THEFT', 'reported_crime': 2913},
#  {'crime_month_name': 'May',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 792},
#  {'crime_month_name': 'November',
#   'primary_type': 'ARSON',
#   'reported_crime': 50},
#  {'crime_month_name': 'November',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1337},
#  {'crime_month_name': 'November',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3013},
#  {'crime_month_name': 'November',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 619},
#  {'crime_month_name': 'November',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'November',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 1888},
#  {'crime_month_name': 'November',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 94},
#  {'crime_month_name': 'November',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 270},
#  {'crime_month_name': 'November',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 2009},
#  {'crime_month_name': 'November',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 3},
#  {'crime_month_name': 'November',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 63},
#  {'crime_month_name': 'November',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 34},
#  {'crime_month_name': 'November',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 13},
#  {'crime_month_name': 'November',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 7},
#  {'crime_month_name': 'November',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 3},
#  {'crime_month_name': 'November',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 937},
#  {'crime_month_name': 'November',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 507},
#  {'crime_month_name': 'November',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 1},
#  {'crime_month_name': 'November',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 144},
#  {'crime_month_name': 'November',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 942},
#  {'crime_month_name': 'November',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 4},
#  {'crime_month_name': 'November',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'crime_month_name': 'November',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 47},
#  {'crime_month_name': 'November',
#   'primary_type': 'RITUALISM',
#   'reported_crime': 1},
#  {'crime_month_name': 'November',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 756},
#  {'crime_month_name': 'November',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 66},
#  {'crime_month_name': 'November',
#   'primary_type': 'STALKING',
#   'reported_crime': 21},
#  {'crime_month_name': 'November',
#   'primary_type': 'THEFT',
#   'reported_crime': 2957},
#  {'crime_month_name': 'November',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 777},
#  {'crime_month_name': 'October',
#   'primary_type': 'ARSON',
#   'reported_crime': 54},
#  {'crime_month_name': 'October',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1512},
#  {'crime_month_name': 'October',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3416},
#  {'crime_month_name': 'October',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 643},
#  {'crime_month_name': 'October',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 14},
#  {'crime_month_name': 'October',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2141},
#  {'crime_month_name': 'October',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 103},
#  {'crime_month_name': 'October',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 315},
#  {'crime_month_name': 'October',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 2025},
#  {'crime_month_name': 'October',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 1},
#  {'crime_month_name': 'October',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 68},
#  {'crime_month_name': 'October',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 53},
#  {'crime_month_name': 'October',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 20},
#  {'crime_month_name': 'October',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 12},
#  {'crime_month_name': 'October',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 11},
#  {'crime_month_name': 'October',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 998},
#  {'crime_month_name': 'October',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 624},
#  {'crime_month_name': 'October',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 8},
#  {'crime_month_name': 'October',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 148},
#  {'crime_month_name': 'October',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1061},
#  {'crime_month_name': 'October',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 4},
#  {'crime_month_name': 'October',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'crime_month_name': 'October',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 66},
#  {'crime_month_name': 'October',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 756},
#  {'crime_month_name': 'October',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 82},
#  {'crime_month_name': 'October',
#   'primary_type': 'STALKING',
#   'reported_crime': 18},
#  {'crime_month_name': 'October',
#   'primary_type': 'THEFT',
#   'reported_crime': 3418},
#  {'crime_month_name': 'October',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 806},
#  {'crime_month_name': 'September',
#   'primary_type': 'ARSON',
#   'reported_crime': 55},
#  {'crime_month_name': 'September',
#   'primary_type': 'ASSAULT',
#   'reported_crime': 1698},
#  {'crime_month_name': 'September',
#   'primary_type': 'BATTERY',
#   'reported_crime': 3440},
#  {'crime_month_name': 'September',
#   'primary_type': 'BURGLARY',
#   'reported_crime': 612},
#  {'crime_month_name': 'September',
#   'primary_type': 'CONCEALED CARRY LICENSE VIOLATION',
#   'reported_crime': 17},
#  {'crime_month_name': 'September',
#   'primary_type': 'CRIMINAL DAMAGE',
#   'reported_crime': 2167},
#  {'crime_month_name': 'September',
#   'primary_type': 'CRIMINAL SEXUAL ASSAULT',
#   'reported_crime': 96},
#  {'crime_month_name': 'September',
#   'primary_type': 'CRIMINAL TRESPASS',
#   'reported_crime': 374},
#  {'crime_month_name': 'September',
#   'primary_type': 'DECEPTIVE PRACTICE',
#   'reported_crime': 1171},
#  {'crime_month_name': 'September',
#   'primary_type': 'GAMBLING',
#   'reported_crime': 3},
#  {'crime_month_name': 'September',
#   'primary_type': 'HOMICIDE',
#   'reported_crime': 82},
#  {'crime_month_name': 'September',
#   'primary_type': 'HUMAN TRAFFICKING',
#   'reported_crime': 1},
#  {'crime_month_name': 'September',
#   'primary_type': 'INTERFERENCE WITH PUBLIC OFFICER',
#   'reported_crime': 34},
#  {'crime_month_name': 'September',
#   'primary_type': 'INTIMIDATION',
#   'reported_crime': 20},
#  {'crime_month_name': 'September',
#   'primary_type': 'KIDNAPPING',
#   'reported_crime': 14},
#  {'crime_month_name': 'September',
#   'primary_type': 'LIQUOR LAW VIOLATION',
#   'reported_crime': 15},
#  {'crime_month_name': 'September',
#   'primary_type': 'MOTOR VEHICLE THEFT',
#   'reported_crime': 921},
#  {'crime_month_name': 'September',
#   'primary_type': 'NARCOTICS',
#   'reported_crime': 558},
#  {'crime_month_name': 'September',
#   'primary_type': 'OBSCENITY',
#   'reported_crime': 3},
#  {'crime_month_name': 'September',
#   'primary_type': 'OFFENSE INVOLVING CHILDREN',
#   'reported_crime': 157},
#  {'crime_month_name': 'September',
#   'primary_type': 'OTHER OFFENSE',
#   'reported_crime': 1054},
#  {'crime_month_name': 'September',
#   'primary_type': 'PROSTITUTION',
#   'reported_crime': 48},
#  {'crime_month_name': 'September',
#   'primary_type': 'PUBLIC INDECENCY',
#   'reported_crime': 1},
#  {'crime_month_name': 'September',
#   'primary_type': 'PUBLIC PEACE VIOLATION',
#   'reported_crime': 66},
#  {'crime_month_name': 'September',
#   'primary_type': 'ROBBERY',
#   'reported_crime': 743},
#  {'crime_month_name': 'September',
#   'primary_type': 'SEX OFFENSE',
#   'reported_crime': 67},
#  {'crime_month_name': 'September',
#   'primary_type': 'STALKING',
#   'reported_crime': 16},
#  {'crime_month_name': 'September',
#   'primary_type': 'THEFT',
#   'reported_crime': 3618},
#  {'crime_month_name': 'September',
#   'primary_type': 'WEAPONS VIOLATION',
#   'reported_crime': 831}]

# %% [markdown]
# ### Loading Data to MONGODB  Database

# %% [markdown]
# #### Cleaning the raw json by removing extra columns

# %%
# Get rid of unnecessary columns
for property in crime_data:
    properties = (property['properties'])
    del (properties['iucr'])
    del (properties['updated_on'])
    del (properties['fbi_code'])
    del (properties['case_number'])
    del (properties['ward'])   
    del (properties['beat'])
    del (properties['community_area'])
    del (properties['location_zip'])
    del (properties['location_city'])

# %%
crime_data[0]
# Out:
# {'type': 'Feature',
#  'geometry': {'type': 'Point', 'coordinates': [-87.561272312, 41.764728045]},
#  'properties': {'location_state': '',
#   'x_coordinate': '1194878',
#   'domestic': False,
#   'latitude': '41.764728045',
#   'description': 'FIRST DEGREE MURDER',
#   'location_address': '',
#   'arrest': True,
#   'year': '2020',
#   'longitude': '-87.561272312',
#   'block': '072XX S SOUTH SHORE DR',
#   'id': '24889',
#   'date': '2020-01-02T02:54:00.000',
#   'y_coordinate': '1857803',
#   'location_description': 'APARTMENT',
#   'district': '003',
#   'primary_type': 'HOMICIDE'}}

# %%
conn = 'mongodb://localhost:27017'
#conn = 'mongodb+srv://chicago_crime_user:chicago_crime_password@cluster0.opshg.mongodb.net/CHICAGO_CRIME_GROUPPROJECT?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime

# %%
collection = db.events

# %%
collection.insert_many(crime_data)

# %%
# query the classroom collection in flask application
#classroom = db.classroom.find()
crime = collection.find()

# %%
crime.count()
# Out:
# <ipython-input-22-c7bd921b95df>:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   crime.count()
# 211359

# %% [markdown]
# ### Loading Crime Type Dictonary in Mongo Shared

# %%
#conn = 'mongodb+srv://chicago_crime_user:chicago_crime_password@cluster0.opshg.mongodb.net/CHICAGO_CRIME_GROUPPROJECT?retryWrites=true&w=majority'
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Define the database in Mongo
db = client.chicago_crime

# %%
collection = db.crime_type_summary

# %%
collection.insert_many(crime_type_dict)
